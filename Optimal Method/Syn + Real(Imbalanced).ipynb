# %%
import pandas as pd
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
import warnings
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression, SGDClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import f1_score, classification_report, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap

# %%
warnings.filterwarnings(action='ignore')

# %%
# Load Synthetic Data

gaussian_copula = pd.read_csv('Synthetic_data(Gaussian Copula).csv', index_col=False)
gaussian_copula = gaussian_copula.iloc[:,1:]

copula_gan = pd.read_csv('Synthetic_data(Copula GAN).csv', index_col=False)
copula_gan = copula_gan.iloc[:,1:]

ctgan = pd.read_csv('Synthetic_data(CTGAN).csv', index_col=False)
ctgan = ctgan.iloc[:,1:]

tave = pd.read_csv('Synthetic_data(TAVE).csv', index_col=False)
tave = tave.iloc[:,1:]


# Load Train Data
x_df = pd.read_csv('x_df.csv')
x_df = x_df.iloc[:, 1:]

# Load Label Data
y_df_binarized = np.load('y_df_binarized.npy')

# Combined df
full_df = x_df
full_df['dna'] = y_df_binarized

# %%
# Data_processing Module
def datasize_check(data, name):
    '''
    Data Size Checking

    Return : data shape and class distribution
    '''
    print(f'Data shape of {name}: {data.shape}')
    print(f'Class Distribution : {Counter(data["dna"])}\n')

def making_valid_data(data, number):
    '''
    60 validation dataset 

    Return Validation data
    '''
    df_0 = data[data['dna'] == 0].sample(number, random_state=42)
    df_1 = data[data['dna'] == 1].sample(number, random_state=42)

    result = pd.concat([df_0, df_1])

    train = data.drop(result.index)

    return train, result

def prepare_vis_com_data(data, synthetic):


    data = data.copy()
    synthetic = synthetic.copy()
    
    data['source'] = "Real"
    synthetic['source'] = "Synthetic"
    combined = pd.concat([data, synthetic], axis=0)
    
    features = combined.drop(columns=['dna', 'source'])
    labels = combined['source']
    
    return features, labels

def break_imbal(synthetic):
    synthetic_1 = synthetic[synthetic['dna'] == 1]

    return synthetic_1

# Model Training Module
def data_split(data, target, size):
    '''
    Train test Data Split

    Return:
    train & test data
    '''
    x_df = data.drop(columns=target)
    y_df = data[target]

    X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, stratify=y_df, test_size=size, random_state=42)

    y_train = np.ravel(y_train)
    y_test = np.ravel(y_test)

    print(f'Train Target Count: {Counter(y_train)}')
    print(f'Test Target Count: {Counter(y_test)}')

    return X_train, X_test, y_train, y_test

def ML_train(X_train, X_test, y_train, y_test, model_name):

    '''
    Machine Learning for   SVM , Logistic, SGD, LGBM

    Return:

    '''

    if model_name == 'SVM':
        
        # Class weight Setting
        class_weight = {0: 2, 1: 1.7}

        # SVM Parmeter Setting
        param_grid = {
        'C': [0.1, 1, 10],
        'gamma': ['scale', 'auto'],
        'kernel': ['linear', 'rbf', 'poly']
        }

        # SVM Model Setting
        model = SVC(random_state=42, class_weight=class_weight)


    elif model_name == 'Logistic':
        # Class weight Setting
        class_weight = {0: 1, 1: 1}

        # Logistic Parmeter Setting
        param_grid = {
        'C': [0.1, 1, 10],
        'penalty' : ['l1', 'l2']
        }

        # Logistic Model Setting
        model = LogisticRegression(random_state=42, class_weight=class_weight)

    elif model_name == 'SGD':
        # Class weight Setting
        class_weight = {0: 2, 1: 3}

        # SGD Parmeter Setting
        param_grid = {
        'alpha': [0.0001, 0.001, 0.01, 0.1],
        'penalty' : ['l1', 'l2']
        }
        # SGD Model Setting
        model = SGDClassifier(random_state=42, class_weight=class_weight)

    elif model_name == 'LGBM':
        # LightGBM Parameter Setting
        param_grid = {
        'learning_rate': [0.01, 0.1, 0.3],
        'n_estimators': [100, 200],
        'max_depth': [3, 5, 7]
        }
        # LightGBM Model Setting
        model = LGBMClassifier(random_state=42, scale_pos_weight=3) 

    else:
        print('Check Model Name.')




    # Best Parameter Searching
    result = {}

    # Stratified K-Fold Setting
    stratified_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    print(f"Training {model_name}...\n")
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=stratified_kfold, scoring='roc_auc_ovr', verbose=1, n_jobs=-1)
    grid_search.fit(X_train, y_train)

    # Best Parameters & 5 Fold-cross validation
    cv_results = grid_search.cv_results_

    fold_f1_scores = []
    for i in range(5):
        print(f'Fold {i+1} Training ................\n')

    print(f"Best Parameters for {model_name}:")
    print(grid_search.best_params_)

    # Prediction with best estimator
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(X_test)

    # AUC ROC Calculation
    if model_name == 'LGBM':
        auc_roc = roc_auc_score(y_test, best_model.predict_proba(X_test)[:, 1])
    else:
        auc_roc = roc_auc_score(y_test, best_model.decision_function(X_test))

    # Assessment score present
    print(f"\nTest Result for {model_name}:")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Generate classification report as a dictionary
    report = classification_report(y_test, y_pred, output_dict=True)

    # Store result 
    result[model_name] = {
        'f1_score': report['weighted avg']['f1-score'],
        'accuracy': report['accuracy']
    }

    # Final Results Reporting
    print(f"\n{model_name} Test Results:")
    print(f"{model_name} F1-score : {result[model_name]['f1_score']: .4f}, AUC ROC : {auc_roc:.4f}, Accuracy : {result[model_name]['accuracy']:.4f}")

    return best_model, result
 
def val_result(data, model):
    y_pred = model.predict(data.drop(columns='dna'))
    print(classification_report(data['dna'], y_pred))
    result = classification_report(data['dna'], y_pred, output_dict=True)

    report_df = pd.DataFrame(result).transpose()

    model_name = model.__class__.__name__
    report_df.to_excel(f'{model_name}_classification_result.xlsx')
    
    return report_df



# Visualization module

def vis_bar(results, model_names):

    metrics = ['Accuracy', 'Weighted F1-Score']
    data = []

    for result, name in zip(results, model_names):
        accuracy = result.loc['accuracy', 'precision']
        weighted_f1 = result.loc['weighted avg', 'f1-score']
        data.append([name, accuracy, weighted_f1])

    plot_df = pd.DataFrame(data, columns=["Model", "Accuracy", "Weighted F1-Score"])


    ax = plot_df.set_index('Model').plot(kind='bar', figsize=(8, 6))
    plt.title('Comparison of Model Performance')
    plt.ylabel('Score')
    plt.ylim(0, 1)
    plt.xticks(rotation=0)
    plt.legend(title="Metrics")

    for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}',
                    (p.get_x() + p.get_width() / 2, p.get_height()),
                    ha='center', va='bottom', fontsize=10)

    plt.tight_layout()
    plt.show()

def visualize_dim_reduction(data, labels, method='pca', random_state=42, **kwargs):
    
    if method.lower() == 'pca':
        reducer = PCA(n_components=2, **kwargs)
    elif method.lower() == 'tsne':
        reducer = TSNE(n_components=2, random_state=random_state, **kwargs)
    elif method.lower() == 'umap':
        reducer = umap.UMAP(n_components=2, random_state=random_state, **kwargs)
    else:
        raise ValueError('Invalid method. Choose from "pca", "tsne", "umap"')
    

    reduced_data = reducer.fit_transform(data)

    # Visualization
    plt.figure(figsize=(8, 6))
    unique_labels = np.unique(labels)

    colors = ['red', 'blue']

    for i, label in enumerate(unique_labels):
        idx = labels == label
        plt.scatter(reduced_data[idx, 0], reduced_data[idx, 1], label=label, alpha=0.3,
                    s=15, c=colors[i])
    plt.title(f'{method.upper()} Visualization')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Data Size Chekcing
datasize_check(gaussian_copula, 'Gaussian_Copula')
datasize_check(copula_gan, 'Copula_GAN')
datasize_check(ctgan, 'CTGAN')
datasize_check(tave, 'TAVE')
datasize_check(full_df, 'Training Data')
# Out:
# Data shape of Gaussian_Copula: (1841, 737)
# Class Distribution : Counter({0: 1578, 1: 263})
#
# Data shape of Copula_GAN: (1841, 737)
# Class Distribution : Counter({0: 1578, 1: 263})
#
# Data shape of CTGAN: (1841, 737)
# Class Distribution : Counter({0: 1578, 1: 263})
#
# Data shape of TAVE: (1841, 737)
# Class Distribution : Counter({0: 1578, 1: 263})
#
# Data shape of Training Data: (357, 737)
# Class Distribution : Counter({0: 306, 1: 51})

# %%
# Ready for validation dataset
train, val_df = making_valid_data(full_df, 30)

datasize_check(val_df, 'Validation Data')
# Out:
# Data shape of Validation Data: (60, 737)
# Class Distribution : Counter({0: 30, 1: 30})

# %% [markdown]
# ## Gaussian Copula

# %%
# Check Batch Effect
features, labels = prepare_vis_com_data(train, gaussian_copula)

visualize_dim_reduction(features, labels, method='pca')
visualize_dim_reduction(features, labels, method='tsne')
visualize_dim_reduction(features, labels, method='umap')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 visualize_dim_reduction(features, labels, method='pca')
#       5 visualize_dim_reduction(features, labels, method='tsne')
# ----> 6 visualize_dim_reduction(features, labels, method='umap')
#
# Cell In[4], line 238, in visualize_dim_reduction(data, labels, method, random_state, **kwargs)
#     234 else:
#     235     raise ValueError('Invalid method. Choose from "pca", "tsne", "umap"')
# --> 238 reduced_data = reducer.fit_transform(data)
#     240 # Visualization
#     241 plt.figure(figsize=(8, 6))
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\umap\umap_.py:2891, in UMAP.fit_transform(self, X, y, force_all_finite)
#    2855 def fit_transform(self, X, y=None, force_all_finite=True):
#    2856     """Fit X into an embedded space and return that transformed
#    2857     output.
#    2858
#    (...)
#    2889         Local radii of data points in the embedding (log-transformed).
#    2890     """
# -> 2891     self.fit(X, y, force_all_finite)
#    2892     if self.transform_mode == "embedding":
#    2893         if self.output_dens:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\umap\umap_.py:2570, in UMAP.fit(self, X, y, force_all_finite)
#    2563 edges_removed = np.sum(dmat >= self._disconnection_distance)
#    2564 dmat[dmat >= self._disconnection_distance] = np.inf
#    2565 (
#    2566     self.graph_,
#    2567     self._sigmas,
#    2568     self._rhos,
#    2569     self.graph_dists_,
# -> 2570 ) = fuzzy_simplicial_set(
#    2571     dmat,
#    2572     self._n_neighbors,
#    2573     random_state,
#    2574     "precomputed",
#    2575     self._metric_kwds,
#    2576     None,
#    2577     None,
#    2578     self.angular_rp_forest,
#    2579     self.set_op_mix_ratio,
#    2580     self.local_connectivity,
#    2581     True,
#    2582     self.verbose,
#    2583     self.densmap or self.output_dens,
#    2584 )
#    2585 # Report the number of vertices with degree 0 in our umap.graph_
#    2586 # This ensures that they were properly disconnected.
#    2587 vertices_disconnected = np.sum(
#    2588     np.array(self.graph_.sum(axis=1)).flatten() == 0
#    2589 )
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\umap\umap_.py:566, in fuzzy_simplicial_set(X, n_neighbors, random_state, metric, metric_kwds, knn_indices, knn_dists, angular, set_op_mix_ratio, local_connectivity, apply_set_operations, verbose, return_dists)
#     457 """Given a set of data X, a neighborhood size, and a measure of distance
#     458 compute the fuzzy simplicial set (here represented as a fuzzy graph in
#     459 the form of a sparse matrix) associated to the data. This is done by
#    (...)
#     563     1-simplex between the ith and jth sample points.
#     564 """
#     565 if knn_indices is None or knn_dists is None:
# --> 566     knn_indices, knn_dists, _ = nearest_neighbors(
#     567         X,
#     568         n_neighbors,
#     569         metric,
#     570         metric_kwds,
#     571         angular,
#     572         random_state,
#     573         verbose=verbose,
#     574     )
#     576 knn_dists = knn_dists.astype(np.float32)
#     578 sigmas, rhos = smooth_knn_dist(
#     579     knn_dists,
#     580     float(n_neighbors),
#     581     local_connectivity=float(local_connectivity),
#     582 )
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\umap\umap_.py:315, in nearest_neighbors(X, n_neighbors, metric, metric_kwds, angular, random_state, low_memory, use_pynndescent, n_jobs, verbose)
#     310     print(ts(), "Finding Nearest Neighbors")
#     312 if metric == "precomputed":
#     313     # Note that this does not support sparse distance matrices yet ...
#     314     # Compute indices of n nearest neighbors
# --> 315     knn_indices = fast_knn_indices(X, n_neighbors)
#     316     # knn_indices = np.argsort(X)[:, :n_neighbors]
#     317     # Compute the nearest neighbor distances
#     318     #   (equivalent to np.sort(X)[:,:n_neighbors])
#     319     knn_dists = X[np.arange(X.shape[0])[:, None], knn_indices].copy()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:375, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     373 return_val = None
#     374 try:
# --> 375     return_val = self.compile(tuple(argtypes))
#     376 except errors.ForceLiteralArg as e:
#     377     # Received request for compiler re-entry with the list of arguments
#     378     # indicated by e.requested_args.
#     379     # First, check if any of these args are already Literal-ized
#     380     already_lit_pos = [i for i in e.requested_args
#     381                        if isinstance(args[i], types.Literal)]
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:905, in Dispatcher.compile(self, sig)
#     903 with ev.trigger_event("numba:compile", data=ev_details):
#     904     try:
# --> 905         cres = self._compiler.compile(args, return_type)
#     906     except errors.ForceLiteralArg as e:
#     907         def folded(args, kws):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:744, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     720 """Compiler entry point
#     721
#     722 Parameter
#    (...)
#     740     compiler pipeline
#     741 """
#     742 pipeline = pipeline_class(typingctx, targetctx, library,
#     743                           args, return_type, flags, locals)
# --> 744 return pipeline.compile_extra(func)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:438, in CompilerBase.compile_extra(self, func)
#     436 self.state.lifted = ()
#     437 self.state.lifted_from = None
# --> 438 return self._compile_bytecode()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:506, in CompilerBase._compile_bytecode(self)
#     502 """
#     503 Populate and run pipeline for bytecode input
#     504 """
#     505 assert self.state.func_ir is None
# --> 506 return self._compile_core()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:472, in CompilerBase._compile_core(self)
#     470 res = None
#     471 try:
# --> 472     pm.run(self.state)
#     473     if self.state.cr is not None:
#     474         break
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typed_passes.py:468, in BaseNativeLowering.run_pass(self, state)
#     465 with targetctx.push_code_library(library):
#     466     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     467                                 metadata=metadata)
# --> 468     lower.lower()
#     469     if not flags.no_cpython_wrapper:
#     470         lower.create_cpython_wrapper(flags.release_gil)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:187, in BaseLower.lower(self)
#     185 if self.generator_info is None:
#     186     self.genlower = None
# --> 187     self.lower_normal_function(self.fndesc)
#     188 else:
#     189     self.genlower = self.GeneratorLower(self)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:226, in BaseLower.lower_normal_function(self, fndesc)
#     224 # Init argument values
#     225 self.extract_function_arguments()
# --> 226 entry_block_tail = self.lower_function_body()
#     228 # Close tail of entry block, do not emit debug metadata else the
#     229 # unconditional jump gets associated with the metadata from the function
#     230 # body end.
#     231 with debuginfo.suspend_emission(self.builder):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:256, in BaseLower.lower_function_body(self)
#     254     self.builder.position_at_end(bb)
#     255     self.debug_print(f"# lower block: {offset}")
# --> 256     self.lower_block(block)
#     257 self.post_lower()
#     258 return entry_block_tail
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:270, in BaseLower.lower_block(self, block)
#     267     defaulterrcls = partial(LoweringError, loc=self.loc)
#     268     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     269                            loc=self.loc, errcls_=defaulterrcls):
# --> 270         self.lower_inst(inst)
#     271 self.post_block(block)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\parfors\parfor_lowering.py:51, in ParforLower.lower_inst(self, inst)
#      49 def lower_inst(self, inst):
#      50     if isinstance(inst, parfor.Parfor):
# ---> 51         _lower_parfor_parallel(self, inst)
#      52     else:
#      53         super().lower_inst(inst)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\parfors\parfor_lowering.py:67, in _lower_parfor_parallel(lowerer, parfor)
#      65 def _lower_parfor_parallel(lowerer, parfor):
#      66     if parfor.lowerer is None:
# ---> 67         return _lower_parfor_parallel_std(lowerer, parfor)
#      68     else:
#      69         return parfor.lowerer(lowerer, parfor)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\parfors\parfor_lowering.py:349, in _lower_parfor_parallel_std(lowerer, parfor)
#     343 numba.parfors.parfor.sequential_parfor_lowering = True
#     344 try:
#     345     (func,
#     346      func_args,
#     347      func_sig,
#     348      func_arg_types,
# --> 349      exp_name_to_tuple_var) = _create_gufunc_for_parfor_body(
#     350         lowerer, parfor, typemap, typingctx, targetctx, flags, {},
#     351         bool(alias_map), index_var_typ, parfor.races)
#     352 finally:
#     353     numba.parfors.parfor.sequential_parfor_lowering = False
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\parfors\parfor_lowering.py:1586, in _create_gufunc_for_parfor_body(lowerer, parfor, typemap, typingctx, targetctx, flags, locals, has_aliases, index_var_typ, races)
#    1583         pm.finalize()
#    1584         return [pm]
# -> 1586 kernel_func = compiler.compile_ir(
#    1587     typingctx,
#    1588     targetctx,
#    1589     gufunc_ir,
#    1590     gufunc_param_types,
#    1591     types.none,
#    1592     flags,
#    1593     locals,
#    1594     pipeline_class=ParforGufuncCompiler)
#    1596 flags.noalias = old_alias
#    1598 kernel_sig = signature(types.none, *gufunc_param_types)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:807, in compile_ir(typingctx, targetctx, func_ir, args, return_type, flags, locals, lifted, lifted_from, is_lifted_loop, library, pipeline_class)
#     804 else:
#     805     pipeline = pipeline_class(typingctx, targetctx, library,
#     806                               args, return_type, flags, locals)
# --> 807     return pipeline.compile_ir(func_ir=func_ir, lifted=lifted,
#     808                                lifted_from=lifted_from)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:448, in CompilerBase.compile_ir(self, func_ir, lifted, lifted_from)
#     445 self.state.nargs = self.state.func_ir.arg_count
#     447 FixupArgs().run_pass(self.state)
# --> 448 return self._compile_ir()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:513, in CompilerBase._compile_ir(self)
#     509 """
#     510 Populate and run pipeline for IR input
#     511 """
#     512 assert self.state.func_ir is not None
# --> 513 return self._compile_core()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:472, in CompilerBase._compile_core(self)
#     470 res = None
#     471 try:
# --> 472     pm.run(self.state)
#     473     if self.state.cr is not None:
#     474         break
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typed_passes.py:468, in BaseNativeLowering.run_pass(self, state)
#     465 with targetctx.push_code_library(library):
#     466     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     467                                 metadata=metadata)
# --> 468     lower.lower()
#     469     if not flags.no_cpython_wrapper:
#     470         lower.create_cpython_wrapper(flags.release_gil)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:187, in BaseLower.lower(self)
#     185 if self.generator_info is None:
#     186     self.genlower = None
# --> 187     self.lower_normal_function(self.fndesc)
#     188 else:
#     189     self.genlower = self.GeneratorLower(self)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:226, in BaseLower.lower_normal_function(self, fndesc)
#     224 # Init argument values
#     225 self.extract_function_arguments()
# --> 226 entry_block_tail = self.lower_function_body()
#     228 # Close tail of entry block, do not emit debug metadata else the
#     229 # unconditional jump gets associated with the metadata from the function
#     230 # body end.
#     231 with debuginfo.suspend_emission(self.builder):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:256, in BaseLower.lower_function_body(self)
#     254     self.builder.position_at_end(bb)
#     255     self.debug_print(f"# lower block: {offset}")
# --> 256     self.lower_block(block)
#     257 self.post_lower()
#     258 return entry_block_tail
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:270, in BaseLower.lower_block(self, block)
#     267     defaulterrcls = partial(LoweringError, loc=self.loc)
#     268     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     269                            loc=self.loc, errcls_=defaulterrcls):
# --> 270         self.lower_inst(inst)
#     271 self.post_block(block)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\parfors\parfor_lowering.py:53, in ParforLower.lower_inst(self, inst)
#      51     _lower_parfor_parallel(self, inst)
#      52 else:
# ---> 53     super().lower_inst(inst)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:448, in Lower.lower_inst(self, inst)
#     446 if isinstance(inst, ir.Assign):
#     447     ty = self.typeof(inst.target.name)
# --> 448     val = self.lower_assign(ty, inst)
#     449     argidx = None
#     450     # If this is a store from an arg, like x = arg.x then tell debuginfo
#     451     # that this is the arg
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:660, in Lower.lower_assign(self, ty, inst)
#     657     return res
#     659 elif isinstance(value, ir.Expr):
# --> 660     return self.lower_expr(ty, value)
#     662 elif isinstance(value, ir.Var):
#     663     val = self.loadvar(value.name)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:1196, in Lower.lower_expr(self, resty, expr)
#    1193     return res
#    1195 elif expr.op == 'call':
# -> 1196     res = self.lower_call(resty, expr)
#    1197     return res
#    1199 elif expr.op == 'pair_first':
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:925, in Lower.lower_call(self, resty, expr)
#     922     res = self._lower_call_FunctionType(fnty, expr, signature)
#     924 else:
# --> 925     res = self._lower_call_normal(fnty, expr, signature)
#     927 # If lowering the call returned None, interpret that as returning dummy
#     928 # value if the return type of the function is void, otherwise there is
#     929 # a problem
#     930 if res is None:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\lowering.py:1167, in Lower._lower_call_normal(self, fnty, expr, signature)
#    1164     # Prepend the self reference
#    1165     argvals = [the_self] + list(argvals)
# -> 1167 res = impl(self.builder, argvals, self.loc)
#    1168 return res
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\base.py:1190, in _wrap_impl.__call__(self, builder, args, loc)
#    1189 def __call__(self, builder, args, loc=None):
# -> 1190     res = self._imp(self._context, builder, self._sig, args, loc=loc)
#    1191     self._context.add_linking_libs(getattr(self, 'libs', ()))
#    1192     return res
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\base.py:1220, in _wrap_missing_loc.__call__.<locals>.wrapper(*args, **kwargs)
#    1218 def wrapper(*args, **kwargs):
#    1219     kwargs.pop('loc')     # drop unused loc
# -> 1220     return fn(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\np\arrayobj.py:6450, in array_argsort(context, builder, sig, args)
#    6448 innersig = sig.replace(args=sig.args[:1])
#    6449 innerargs = args[:1]
# -> 6450 return context.compile_internal(builder, array_argsort_impl,
#    6451                                 innersig, innerargs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\base.py:881, in BaseContext.compile_internal(self, builder, impl, sig, args, locals)
#     876 def compile_internal(self, builder, impl, sig, args, locals={}):
#     877     """
#     878     Like compile_subroutine(), but also call the function with the given
#     879     *args*.
#     880     """
# --> 881     cres = self.compile_subroutine(builder, impl, sig, locals)
#     882     return self.call_internal(builder, cres.fndesc, sig, args)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\base.py:866, in BaseContext.compile_subroutine(self, builder, impl, sig, locals, flags, caching)
#     864     cached = self.cached_internal_func.get(cache_key)
#     865 if cached is None:
# --> 866     cres = self._compile_subroutine_no_cache(builder, impl, sig,
#     867                                              locals=locals,
#     868                                              flags=flags)
#     869     self.cached_internal_func[cache_key] = cres
#     871 cres = self.cached_internal_func[cache_key]
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\base.py:837, in BaseContext._compile_subroutine_no_cache(self, builder, impl, sig, locals, flags)
#     834 flags.no_cpython_wrapper = True
#     835 flags.no_cfunc_wrapper = True
# --> 837 cres = compiler.compile_internal(self.typing_context, self,
#     838                                  library,
#     839                                  impl, sig.args,
#     840                                  sig.return_type, flags,
#     841                                  locals=locals)
#     843 # Allow inlining the function inside callers.
#     844 self.active_code_library.add_linking_library(cres.library)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:818, in compile_internal(typingctx, targetctx, library, func, args, return_type, flags, locals)
#     813 """
#     814 For internal use only.
#     815 """
#     816 pipeline = Compiler(typingctx, targetctx, library,
#     817                     args, return_type, flags, locals)
# --> 818 return pipeline.compile_extra(func)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:438, in CompilerBase.compile_extra(self, func)
#     436 self.state.lifted = ()
#     437 self.state.lifted_from = None
# --> 438 return self._compile_bytecode()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:506, in CompilerBase._compile_bytecode(self)
#     502 """
#     503 Populate and run pipeline for bytecode input
#     504 """
#     505 assert self.state.func_ir is None
# --> 506 return self._compile_core()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:472, in CompilerBase._compile_core(self)
#     470 res = None
#     471 try:
# --> 472     pm.run(self.state)
#     473     if self.state.cr is not None:
#     474         break
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     106 """
#     107 Type inference and legalization
#     108 """
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#     121     # save errors in case of partial typing
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      91     infer.build_constraint()
#      92     # return errors in case of partial typing
# ---> 93     errs = infer.propagate(raise_errors=raise_errors)
#      94     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      96 return _TypingResults(typemap, restype, calltypes, errs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:1083, in TypeInferer.propagate(self, raise_errors)
#    1080 oldtoken = newtoken
#    1081 # Errors can appear when the type set is incomplete; only
#    1082 # raise them when there is no progress anymore.
# -> 1083 errors = self.constraints.propagate(self)
#    1084 newtoken = self.get_state_token()
#    1085 self.debug.propagate_finished()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:583, in CallConstraint.__call__(self, typeinfer)
#     581     fnty = typevars[self.func].getone()
#     582 with new_error_context("resolving callee type: {0}", fnty):
# --> 583     self.resolve(typeinfer, typevars, fnty)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:606, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     604     fnty = fnty.instance_type
#     605 try:
# --> 606     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     607 except ForceLiteralArg as e:
#     608     # Adjust for bound methods
#     609     folding_args = ((fnty.this,) + tuple(self.args)
#     610                     if isinstance(fnty, types.BoundFunction)
#     611                     else self.args)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:1577, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1574     return sig
#    1575 else:
#    1576     # Normal non-recursive call
# -> 1577     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\context.py:196, in BaseContext.resolve_function_type(self, func, args, kws)
#     194 # Prefer user definition first
#     195 try:
# --> 196     res = self._resolve_user_function_type(func, args, kws)
#     197 except errors.TypingError as e:
#     198     # Capture any typing error
#     199     last_exception = e
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\context.py:248, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     244         return self.resolve_function_type(func_type, args, kws)
#     246 if isinstance(func, types.Callable):
#     247     # XXX fold this into the __call__ attribute logic?
# --> 248     return func.get_call_type(self, args, kws)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\types\functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if (utils.use_new_style_errors() and not
#     311             isinstance(e, errors.NumbaError)):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:350, in AbstractTemplate.apply(self, args, kws)
#     348 def apply(self, args, kws):
#     349     generic = getattr(self, "generic")
# --> 350     sig = generic(args, kws)
#     351     # Enforce that *generic()* must return None or Signature
#     352     if sig is not None:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:613, in _OverloadFunctionTemplate.generic(self, args, kws)
#     607 """
#     608 Type the overloaded function by compiling the appropriate
#     609 implementation for the given args.
#     610 """
#     611 from numba.core.typed_passes import PreLowerStripPhis
# --> 613 disp, new_args = self._get_impl(args, kws)
#     614 if disp is None:
#     615     return
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:712, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     708 except KeyError:
#     709     # pass and try outside the scope so as to not have KeyError with a
#     710     # nested addition error in the case the _build_impl fails
#     711     pass
# --> 712 impl, args = self._build_impl(cache_key, args, kws)
#     713 return impl, args
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:816, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     814 # Make sure that the implementation can be fully compiled
#     815 disp_type = types.Dispatcher(disp)
# --> 816 disp_type.get_call_type(self.context, args, kws)
#     817 if cache_key is not None:
#     818     self._impl_cache[cache_key] = disp, args
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\types\functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:318, in _DispatcherBase.get_call_template(self, args, kws)
#     316 # Ensure an overload is available
#     317 if self._can_compile:
# --> 318     self.compile(tuple(args))
#     320 # Create function type for typing
#     321 func_name = self.py_func.__name__
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:905, in Dispatcher.compile(self, sig)
#     903 with ev.trigger_event("numba:compile", data=ev_details):
#     904     try:
# --> 905         cres = self._compiler.compile(args, return_type)
#     906     except errors.ForceLiteralArg as e:
#     907         def folded(args, kws):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:744, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     720 """Compiler entry point
#     721
#     722 Parameter
#    (...)
#     740     compiler pipeline
#     741 """
#     742 pipeline = pipeline_class(typingctx, targetctx, library,
#     743                           args, return_type, flags, locals)
# --> 744 return pipeline.compile_extra(func)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:438, in CompilerBase.compile_extra(self, func)
#     436 self.state.lifted = ()
#     437 self.state.lifted_from = None
# --> 438 return self._compile_bytecode()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:506, in CompilerBase._compile_bytecode(self)
#     502 """
#     503 Populate and run pipeline for bytecode input
#     504 """
#     505 assert self.state.func_ir is None
# --> 506 return self._compile_core()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:472, in CompilerBase._compile_core(self)
#     470 res = None
#     471 try:
# --> 472     pm.run(self.state)
#     473     if self.state.cr is not None:
#     474         break
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     106 """
#     107 Type inference and legalization
#     108 """
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#     121     # save errors in case of partial typing
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      91     infer.build_constraint()
#      92     # return errors in case of partial typing
# ---> 93     errs = infer.propagate(raise_errors=raise_errors)
#      94     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      96 return _TypingResults(typemap, restype, calltypes, errs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:1083, in TypeInferer.propagate(self, raise_errors)
#    1080 oldtoken = newtoken
#    1081 # Errors can appear when the type set is incomplete; only
#    1082 # raise them when there is no progress anymore.
# -> 1083 errors = self.constraints.propagate(self)
#    1084 newtoken = self.get_state_token()
#    1085 self.debug.propagate_finished()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:583, in CallConstraint.__call__(self, typeinfer)
#     581     fnty = typevars[self.func].getone()
#     582 with new_error_context("resolving callee type: {0}", fnty):
# --> 583     self.resolve(typeinfer, typevars, fnty)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:606, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     604     fnty = fnty.instance_type
#     605 try:
# --> 606     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     607 except ForceLiteralArg as e:
#     608     # Adjust for bound methods
#     609     folding_args = ((fnty.this,) + tuple(self.args)
#     610                     if isinstance(fnty, types.BoundFunction)
#     611                     else self.args)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:1577, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1574     return sig
#    1575 else:
#    1576     # Normal non-recursive call
# -> 1577     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\context.py:196, in BaseContext.resolve_function_type(self, func, args, kws)
#     194 # Prefer user definition first
#     195 try:
# --> 196     res = self._resolve_user_function_type(func, args, kws)
#     197 except errors.TypingError as e:
#     198     # Capture any typing error
#     199     last_exception = e
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\context.py:248, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     244         return self.resolve_function_type(func_type, args, kws)
#     246 if isinstance(func, types.Callable):
#     247     # XXX fold this into the __call__ attribute logic?
# --> 248     return func.get_call_type(self, args, kws)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\types\functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if (utils.use_new_style_errors() and not
#     311             isinstance(e, errors.NumbaError)):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:350, in AbstractTemplate.apply(self, args, kws)
#     348 def apply(self, args, kws):
#     349     generic = getattr(self, "generic")
# --> 350     sig = generic(args, kws)
#     351     # Enforce that *generic()* must return None or Signature
#     352     if sig is not None:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:613, in _OverloadFunctionTemplate.generic(self, args, kws)
#     607 """
#     608 Type the overloaded function by compiling the appropriate
#     609 implementation for the given args.
#     610 """
#     611 from numba.core.typed_passes import PreLowerStripPhis
# --> 613 disp, new_args = self._get_impl(args, kws)
#     614 if disp is None:
#     615     return
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:712, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     708 except KeyError:
#     709     # pass and try outside the scope so as to not have KeyError with a
#     710     # nested addition error in the case the _build_impl fails
#     711     pass
# --> 712 impl, args = self._build_impl(cache_key, args, kws)
#     713 return impl, args
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:816, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     814 # Make sure that the implementation can be fully compiled
#     815 disp_type = types.Dispatcher(disp)
# --> 816 disp_type.get_call_type(self.context, args, kws)
#     817 if cache_key is not None:
#     818     self._impl_cache[cache_key] = disp, args
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\types\functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:318, in _DispatcherBase.get_call_template(self, args, kws)
#     316 # Ensure an overload is available
#     317 if self._can_compile:
# --> 318     self.compile(tuple(args))
#     320 # Create function type for typing
#     321 func_name = self.py_func.__name__
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:905, in Dispatcher.compile(self, sig)
#     903 with ev.trigger_event("numba:compile", data=ev_details):
#     904     try:
# --> 905         cres = self._compiler.compile(args, return_type)
#     906     except errors.ForceLiteralArg as e:
#     907         def folded(args, kws):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:744, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     720 """Compiler entry point
#     721
#     722 Parameter
#    (...)
#     740     compiler pipeline
#     741 """
#     742 pipeline = pipeline_class(typingctx, targetctx, library,
#     743                           args, return_type, flags, locals)
# --> 744 return pipeline.compile_extra(func)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:438, in CompilerBase.compile_extra(self, func)
#     436 self.state.lifted = ()
#     437 self.state.lifted_from = None
# --> 438 return self._compile_bytecode()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:506, in CompilerBase._compile_bytecode(self)
#     502 """
#     503 Populate and run pipeline for bytecode input
#     504 """
#     505 assert self.state.func_ir is None
# --> 506 return self._compile_core()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:472, in CompilerBase._compile_core(self)
#     470 res = None
#     471 try:
# --> 472     pm.run(self.state)
#     473     if self.state.cr is not None:
#     474         break
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
# ...
#     581     fnty = typevars[self.func].getone()
#     582 with new_error_context("resolving callee type: {0}", fnty):
# --> 583     self.resolve(typeinfer, typevars, fnty)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:606, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     604     fnty = fnty.instance_type
#     605 try:
# --> 606     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     607 except ForceLiteralArg as e:
#     608     # Adjust for bound methods
#     609     folding_args = ((fnty.this,) + tuple(self.args)
#     610                     if isinstance(fnty, types.BoundFunction)
#     611                     else self.args)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:1577, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1574     return sig
#    1575 else:
#    1576     # Normal non-recursive call
# -> 1577     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\context.py:196, in BaseContext.resolve_function_type(self, func, args, kws)
#     194 # Prefer user definition first
#     195 try:
# --> 196     res = self._resolve_user_function_type(func, args, kws)
#     197 except errors.TypingError as e:
#     198     # Capture any typing error
#     199     last_exception = e
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\context.py:248, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     244         return self.resolve_function_type(func_type, args, kws)
#     246 if isinstance(func, types.Callable):
#     247     # XXX fold this into the __call__ attribute logic?
# --> 248     return func.get_call_type(self, args, kws)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\types\functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if (utils.use_new_style_errors() and not
#     311             isinstance(e, errors.NumbaError)):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:350, in AbstractTemplate.apply(self, args, kws)
#     348 def apply(self, args, kws):
#     349     generic = getattr(self, "generic")
# --> 350     sig = generic(args, kws)
#     351     # Enforce that *generic()* must return None or Signature
#     352     if sig is not None:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:613, in _OverloadFunctionTemplate.generic(self, args, kws)
#     607 """
#     608 Type the overloaded function by compiling the appropriate
#     609 implementation for the given args.
#     610 """
#     611 from numba.core.typed_passes import PreLowerStripPhis
# --> 613 disp, new_args = self._get_impl(args, kws)
#     614 if disp is None:
#     615     return
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:712, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     708 except KeyError:
#     709     # pass and try outside the scope so as to not have KeyError with a
#     710     # nested addition error in the case the _build_impl fails
#     711     pass
# --> 712 impl, args = self._build_impl(cache_key, args, kws)
#     713 return impl, args
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\templates.py:816, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     814 # Make sure that the implementation can be fully compiled
#     815 disp_type = types.Dispatcher(disp)
# --> 816 disp_type.get_call_type(self.context, args, kws)
#     817 if cache_key is not None:
#     818     self._impl_cache[cache_key] = disp, args
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\types\functions.py:541, in Dispatcher.get_call_type(self, context, args, kws)
#     534 def get_call_type(self, context, args, kws):
#     535     """
#     536     Resolve a call to this dispatcher using the given argument types.
#     537     A signature returned and it is ensured that a compiled specialization
#     538     is available for it.
#     539     """
#     540     template, pysig, args, kws = \
# --> 541         self.dispatcher.get_call_template(args, kws)
#     542     sig = template(context).apply(args, kws)
#     543     if sig:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:318, in _DispatcherBase.get_call_template(self, args, kws)
#     316 # Ensure an overload is available
#     317 if self._can_compile:
# --> 318     self.compile(tuple(args))
#     320 # Create function type for typing
#     321 func_name = self.py_func.__name__
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:905, in Dispatcher.compile(self, sig)
#     903 with ev.trigger_event("numba:compile", data=ev_details):
#     904     try:
# --> 905         cres = self._compiler.compile(args, return_type)
#     906     except errors.ForceLiteralArg as e:
#     907         def folded(args, kws):
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:744, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     720 """Compiler entry point
#     721
#     722 Parameter
#    (...)
#     740     compiler pipeline
#     741 """
#     742 pipeline = pipeline_class(typingctx, targetctx, library,
#     743                           args, return_type, flags, locals)
# --> 744 return pipeline.compile_extra(func)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:438, in CompilerBase.compile_extra(self, func)
#     436 self.state.lifted = ()
#     437 self.state.lifted_from = None
# --> 438 return self._compile_bytecode()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:506, in CompilerBase._compile_bytecode(self)
#     502 """
#     503 Populate and run pipeline for bytecode input
#     504 """
#     505 assert self.state.func_ir is None
# --> 506 return self._compile_core()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler.py:472, in CompilerBase._compile_core(self)
#     470 res = None
#     471 try:
# --> 472     pm.run(self.state)
#     473     if self.state.cr is not None:
#     474         break
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     106 """
#     107 Type inference and legalization
#     108 """
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#     121     # save errors in case of partial typing
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typed_passes.py:93, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      91     infer.build_constraint()
#      92     # return errors in case of partial typing
# ---> 93     errs = infer.propagate(raise_errors=raise_errors)
#      94     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      96 return _TypingResults(typemap, restype, calltypes, errs)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:1083, in TypeInferer.propagate(self, raise_errors)
#    1080 oldtoken = newtoken
#    1081 # Errors can appear when the type set is incomplete; only
#    1082 # raise them when there is no progress anymore.
# -> 1083 errors = self.constraints.propagate(self)
#    1084 newtoken = self.get_state_token()
#    1085 self.debug.propagate_finished()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:708, in IntrinsicCallConstraint.__call__(self, typeinfer)
#     706 fnty = self.func
#     707 if fnty in utils.OPERATORS_TO_BUILTINS:
# --> 708     fnty = typeinfer.resolve_value_type(None, fnty)
#     709 self.resolve(typeinfer, typeinfer.typevars, fnty=fnty)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typeinfer.py:1499, in TypeInferer.resolve_value_type(self, inst, val)
#    1494 """
#    1495 Resolve the type of a simple Python value, such as can be
#    1496 represented by literals.
#    1497 """
#    1498 try:
# -> 1499     return self.context.resolve_value_type(val)
#    1500 except ValueError as e:
#    1501     msg = str(e)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\context.py:381, in BaseContext.resolve_value_type(self, val)
#     375 """
#     376 Return the numba type of a Python value that is being used
#     377 as a runtime constant.
#     378 ValueError is raised for unsupported types.
#     379 """
#     380 try:
# --> 381     ty = typeof(val, Purpose.constant)
#     382 except ValueError as e:
#     383     # Make sure the exception doesn't hold a reference to the user
#     384     # value.
#     385     typeof_exc = utils.erase_traceback(e)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\typing\typeof.py:35, in typeof(val, purpose)
#      33 ty = typeof_impl(val, c)
#      34 if ty is None:
# ---> 35     msg = _termcolor.errmsg(
#      36         f"Cannot determine Numba type of {type(val)}")
#      37     raise ValueError(msg)
#      38 return ty
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\errors.py:336, in HighlightColorScheme.errmsg(self, msg)
#     335 def errmsg(self, msg):
# --> 336     return self._markup(msg, self._errmsg)
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\errors.py:326, in HighlightColorScheme._markup(self, msg, color, style)
#     324 if style:
#     325     features += style
# --> 326 with ColorShell():
#     327     with reset_terminal() as mu:
#     328         mu += features.encode('utf-8')
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\numba\core\errors.py:244, in ColorShell.__init__(self)
#     243 def __init__(self):
# --> 244     init()
#     245     self._has_initialized = True
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\colorama\initialise.py:52, in init(autoreset, convert, strip, wrap)
#      49     wrapped_stdout = None
#      50 else:
#      51     sys.stdout = wrapped_stdout = \
# ---> 52         wrap_stream(orig_stdout, convert, strip, autoreset, wrap)
#      53 if sys.stderr is None:
#      54     wrapped_stderr = None
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\colorama\initialise.py:113, in wrap_stream(stream, convert, strip, autoreset, wrap)
#     111 def wrap_stream(stream, convert, strip, autoreset, wrap):
#     112     if wrap:
# --> 113         wrapper = AnsiToWin32(stream,
#     114             convert=convert, strip=strip, autoreset=autoreset)
#     115         if wrapper.should_wrap():
#     116             stream = wrapper.stream
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\colorama\ansitowin32.py:96, in AnsiToWin32.__init__(self, wrapped, convert, strip, autoreset)
#      91 on_windows = os.name == 'nt'
#      92 # We test if the WinAPI works, because even if we are on Windows
#      93 # we may be using a terminal that doesn't support the WinAPI
#      94 # (e.g. Cygwin Terminal). In this case it's up to the terminal
#      95 # to support the ANSI codes.
# ---> 96 conversion_supported = on_windows and winapi_test()
#      97 try:
#      98     fd = wrapped.fileno()
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\colorama\win32.py:115, in winapi_test()
#     114 def winapi_test():
# --> 115     return any(_winapi_test(h) for h in
#     116                (_GetStdHandle(STDOUT), _GetStdHandle(STDERR)))
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\colorama\win32.py:115, in <genexpr>(.0)
#     114 def winapi_test():
# --> 115     return any(_winapi_test(h) for h in
#     116                (_GetStdHandle(STDOUT), _GetStdHandle(STDERR)))
#
# File c:\Users\USER\anaconda3\envs\deep\lib\site-packages\colorama\win32.py:110, in _winapi_test(handle)
#     108 def _winapi_test(handle):
#     109     csbi = CONSOLE_SCREEN_BUFFER_INFO()
# --> 110     success = _GetConsoleScreenBufferInfo(
#     111         handle, byref(csbi))
#     112     return bool(success)
#
# KeyboardInterrupt:

# %%
# Combined Data
comb_dat = pd.concat([train, gaussian_copula_1], axis=0)
datasize_check(comb_dat, 'Combined Data')
# Out:
# Data shape of Combined Data: (560, 737)
# Class Distribution : Counter({1: 284, 0: 276})

# %%
# Data Split
X_train, X_test, y_train, y_test = data_split(comb_dat, 'dna', 0.15)

svm_model, svm_result = ML_train(X_train, X_test, y_train, y_test, 'SVM')
logi_model, logi_result = ML_train(X_train, X_test, y_train, y_test, 'Logistic')
sgd_model, sgd_result = ML_train(X_train, X_test, y_train, y_test, 'SGD')
lgbm_model, lgbm_result = ML_train(X_train, X_test, y_train, y_test, 'LGBM')
# Out:
# Train Target Count: Counter({1: 241, 0: 235})
# Test Target Count: Counter({1: 43, 0: 41})
# Training SVM...
#
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for SVM:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
# Test Result for SVM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.68      0.78      0.73        41
#            1       0.76      0.65      0.70        43
#
#     accuracy                           0.71        84
#    macro avg       0.72      0.72      0.71        84
# weighted avg       0.72      0.71      0.71        84
#
#
# SVM Test Results:
# SVM F1-score :  0.7133, AUC ROC : 0.7930, Accuracy : 0.7143
# Training Logistic...
#
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for Logistic:
# {'C': 1, 'penalty': 'l2'}
#
# Test Result for Logistic:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.75        41
#            1       0.78      0.67      0.72        43
#
#     accuracy                           0.74        84
#    macro avg       0.74      0.74      0.74        84
# weighted avg       0.74      0.74      0.74        84
#
#
# Logistic Test Results:
# Logistic F1-score :  0.7372, AUC ROC : 0.7839, Accuracy : 0.7381
# Training SGD...
#
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for SGD:
# {'alpha': 0.0001, 'penalty': 'l1'}
#
# Test Result for SGD:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.77        41
#            1       0.79      0.72      0.76        43
#
#     accuracy                           0.76        84
#    macro avg       0.76      0.76      0.76        84
# weighted avg       0.76      0.76      0.76        84
#
#
# SGD Test Results:
# SGD F1-score :  0.7616, AUC ROC : 0.7873, Accuracy : 0.7619
# Training LGBM...
#
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [LightGBM] [Info] Number of positive: 241, number of negative: 235
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007513 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 117011
# [LightGBM] [Info] Number of data points in the train set: 476, number of used features: 736
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506303 -> initscore=0.025211
# [LightGBM] [Info] Start training from score 0.025211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for LGBM:
# {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}
#
# Test Result for LGBM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83        41
#            1       0.84      0.84      0.84        43
#
#     accuracy                           0.83        84
#    macro avg       0.83      0.83      0.83        84
# weighted avg       0.83      0.83      0.83        84
#
#
# LGBM Test Results:
# LGBM F1-score :  0.8333, AUC ROC : 0.9393, Accuracy : 0.8333

# %%
# Save Validation Results
svm_res = val_result(val_df, svm_model)
logi_res = val_result(val_df, logi_model)
sgd_res = val_result(val_df, sgd_model)
lgbm_res = val_result(val_df, lgbm_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82        30
#            1       0.79      0.90      0.84        30
#
#     accuracy                           0.83        60
#    macro avg       0.84      0.83      0.83        60
# weighted avg       0.84      0.83      0.83        60
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        30
#            1       0.75      0.90      0.82        30
#
#     accuracy                           0.80        60
#    macro avg       0.81      0.80      0.80        60
# weighted avg       0.81      0.80      0.80        60
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.57      0.65        30
#            1       0.66      0.83      0.74        30
#
#     accuracy                           0.70        60
#    macro avg       0.72      0.70      0.69        60
# weighted avg       0.72      0.70      0.69        60
#
#               precision    recall  f1-score   support
#
#            0       0.58      0.83      0.68        30
#            1       0.71      0.40      0.51        30
#
#     accuracy                           0.62        60
#    macro avg       0.64      0.62      0.60        60
# weighted avg       0.64      0.62      0.60        60

# %%
results = [svm_res, logi_res, sgd_res, lgbm_res]
model_names = ["SVM", "Logistic Regression", "SGD", "LightGBM"]

vis_bar(results, model_names)

# %% [markdown]
# ## Copula GAN

# %%
# Check Batch Effect
features, labels = prepare_vis_com_data(train, copula_gan)

visualize_dim_reduction(features, labels, method='pca')
visualize_dim_reduction(features, labels, method='tsne')
visualize_dim_reduction(features, labels, method='umap')

# %%
# Combined Data
comb_dat = pd.concat([train, copula_gan], axis=0)
datasize_check(comb_dat, 'Combined Data')
# Out:
# Data shape of Combined Data: (560, 737)
# Class Distribution : Counter({1: 284, 0: 276})

# %%
# Data Split
X_train, X_test, y_train, y_test = data_split(comb_dat, 'dna', 0.15)

svm_model, svm_result = ML_train(X_train, X_test, y_train, y_test, 'SVM')
logi_model, logi_result = ML_train(X_train, X_test, y_train, y_test, 'Logistic')
sgd_model, sgd_result = ML_train(X_train, X_test, y_train, y_test, 'SGD')
lgbm_model, lgbm_result = ML_train(X_train, X_test, y_train, y_test, 'LGBM')
# Out:
# Train Target Count: Counter({1: 241, 0: 235})
# Test Target Count: Counter({1: 43, 0: 41})
# Training SVM...
#
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for SVM:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
# Test Result for SVM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        41
#            1       0.95      0.93      0.94        43
#
#     accuracy                           0.94        84
#    macro avg       0.94      0.94      0.94        84
# weighted avg       0.94      0.94      0.94        84
#
#
# SVM Test Results:
# SVM F1-score :  0.9405, AUC ROC : 0.9750, Accuracy : 0.9405
# Training Logistic...
#
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for Logistic:
# {'C': 10, 'penalty': 'l2'}
#
# Test Result for Logistic:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        41
#            1       1.00      0.93      0.96        43
#
#     accuracy                           0.96        84
#    macro avg       0.97      0.97      0.96        84
# weighted avg       0.97      0.96      0.96        84
#
#
# Logistic Test Results:
# Logistic F1-score :  0.9643, AUC ROC : 0.9733, Accuracy : 0.9643
# Training SGD...
#
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for SGD:
# {'alpha': 0.0001, 'penalty': 'l1'}
#
# Test Result for SGD:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        41
#            1       0.93      0.95      0.94        43
#
#     accuracy                           0.94        84
#    macro avg       0.94      0.94      0.94        84
# weighted avg       0.94      0.94      0.94        84
#
#
# SGD Test Results:
# SGD F1-score :  0.9405, AUC ROC : 0.9699, Accuracy : 0.9405
# Training LGBM...
#
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [LightGBM] [Info] Number of positive: 241, number of negative: 235
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007940 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 112429
# [LightGBM] [Info] Number of data points in the train set: 476, number of used features: 736
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506303 -> initscore=0.025211
# [LightGBM] [Info] Start training from score 0.025211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for LGBM:
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200}
#
# Test Result for LGBM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        41
#            1       1.00      0.93      0.96        43
#
#     accuracy                           0.96        84
#    macro avg       0.97      0.97      0.96        84
# weighted avg       0.97      0.96      0.96        84
#
#
# LGBM Test Results:
# LGBM F1-score :  0.9643, AUC ROC : 0.9648, Accuracy : 0.9643

# %%
# Save Validation Results
svm_res = val_result(val_df, svm_model)
logi_res = val_result(val_df, logi_model)
sgd_res = val_result(val_df, sgd_model)
lgbm_res = val_result(val_df, lgbm_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.97      0.68        30
#            1       0.80      0.13      0.23        30
#
#     accuracy                           0.55        60
#    macro avg       0.66      0.55      0.46        60
# weighted avg       0.66      0.55      0.46        60
#
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71        30
#            1       1.00      0.17      0.29        30
#
#     accuracy                           0.58        60
#    macro avg       0.77      0.58      0.50        60
# weighted avg       0.77      0.58      0.50        60
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.93      0.66        30
#            1       0.60      0.10      0.17        30
#
#     accuracy                           0.52        60
#    macro avg       0.55      0.52      0.42        60
# weighted avg       0.55      0.52      0.42        60
#
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69        30
#            1       1.00      0.10      0.18        30
#
#     accuracy                           0.55        60
#    macro avg       0.76      0.55      0.44        60
# weighted avg       0.76      0.55      0.44        60

# %%
results = [svm_res, logi_res, sgd_res, lgbm_res]
model_names = ["SVM", "Logistic Regression", "SGD", "LightGBM"]

vis_bar(results, model_names)

# %% [markdown]
# ## CTGAN

# %%
# Check Batch Effect
features, labels = prepare_vis_com_data(train, ctgan)

visualize_dim_reduction(features, labels, method='pca')
visualize_dim_reduction(features, labels, method='tsne')
visualize_dim_reduction(features, labels, method='umap')

# %%
# Combined Data
comb_dat = pd.concat([train, ctgan], axis=0)
datasize_check(comb_dat, 'Combined Data')
# Out:
# Data shape of Combined Data: (560, 737)
# Class Distribution : Counter({1: 284, 0: 276})

# %%
# Data Split
X_train, X_test, y_train, y_test = data_split(comb_dat, 'dna', 0.15)

svm_model, svm_result = ML_train(X_train, X_test, y_train, y_test, 'SVM')
logi_model, logi_result = ML_train(X_train, X_test, y_train, y_test, 'Logistic')
sgd_model, sgd_result = ML_train(X_train, X_test, y_train, y_test, 'SGD')
lgbm_model, lgbm_result = ML_train(X_train, X_test, y_train, y_test, 'LGBM')
# Out:
# Train Target Count: Counter({1: 241, 0: 235})
# Test Target Count: Counter({1: 43, 0: 41})
# Training SVM...
#
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for SVM:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
# Test Result for SVM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90        41
#            1       0.95      0.84      0.89        43
#
#     accuracy                           0.89        84
#    macro avg       0.90      0.89      0.89        84
# weighted avg       0.90      0.89      0.89        84
#
#
# SVM Test Results:
# SVM F1-score :  0.8926, AUC ROC : 0.9455, Accuracy : 0.8929
# Training Logistic...
#
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for Logistic:
# {'C': 0.1, 'penalty': 'l2'}
#
# Test Result for Logistic:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        41
#            1       1.00      0.88      0.94        43
#
#     accuracy                           0.94        84
#    macro avg       0.95      0.94      0.94        84
# weighted avg       0.95      0.94      0.94        84
#
#
# Logistic Test Results:
# Logistic F1-score :  0.9403, AUC ROC : 0.9677, Accuracy : 0.9405
# Training SGD...
#
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for SGD:
# {'alpha': 0.0001, 'penalty': 'l1'}
#
# Test Result for SGD:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        41
#            1       1.00      0.93      0.96        43
#
#     accuracy                           0.96        84
#    macro avg       0.97      0.97      0.96        84
# weighted avg       0.97      0.96      0.96        84
#
#
# SGD Test Results:
# SGD F1-score :  0.9643, AUC ROC : 0.9784, Accuracy : 0.9643
# Training LGBM...
#
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [LightGBM] [Info] Number of positive: 241, number of negative: 235
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007314 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 117025
# [LightGBM] [Info] Number of data points in the train set: 476, number of used features: 736
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506303 -> initscore=0.025211
# [LightGBM] [Info] Start training from score 0.025211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for LGBM:
# {'learning_rate': 0.3, 'max_depth': 3, 'n_estimators': 200}
#
# Test Result for LGBM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        41
#            1       1.00      0.93      0.96        43
#
#     accuracy                           0.96        84
#    macro avg       0.97      0.97      0.96        84
# weighted avg       0.97      0.96      0.96        84
#
#
# LGBM Test Results:
# LGBM F1-score :  0.9643, AUC ROC : 0.9597, Accuracy : 0.9643

# %%
# Save Validation Results
svm_res = val_result(val_df, svm_model)
logi_res = val_result(val_df, logi_model)
sgd_res = val_result(val_df, sgd_model)
lgbm_res = val_result(val_df, lgbm_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.97      0.68        30
#            1       0.80      0.13      0.23        30
#
#     accuracy                           0.55        60
#    macro avg       0.66      0.55      0.46        60
# weighted avg       0.66      0.55      0.46        60
#
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70        30
#            1       1.00      0.13      0.24        30
#
#     accuracy                           0.57        60
#    macro avg       0.77      0.57      0.47        60
# weighted avg       0.77      0.57      0.47        60
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.90      0.66        30
#            1       0.62      0.17      0.26        30
#
#     accuracy                           0.53        60
#    macro avg       0.57      0.53      0.46        60
# weighted avg       0.57      0.53      0.46        60
#
#               precision    recall  f1-score   support
#
#            0       0.53      1.00      0.69        30
#            1       1.00      0.10      0.18        30
#
#     accuracy                           0.55        60
#    macro avg       0.76      0.55      0.44        60
# weighted avg       0.76      0.55      0.44        60

# %%
results = [svm_res, logi_res, sgd_res, lgbm_res]
model_names = ["SVM", "Logistic Regression", "SGD", "LightGBM"]

vis_bar(results, model_names)

# %% [markdown]
# ## TAVE

# %%
# Check Batch Effect
features, labels = prepare_vis_com_data(train, tave)

visualize_dim_reduction(features, labels, method='pca')
visualize_dim_reduction(features, labels, method='tsne')
visualize_dim_reduction(features, labels, method='umap')

# %%
# Combined Data
comb_dat = pd.concat([train, tave], axis=0)
datasize_check(comb_dat, 'Combined Data')
# Out:
# Data shape of Combined Data: (560, 737)
# Class Distribution : Counter({1: 284, 0: 276})

# %%
# Data Split
X_train, X_test, y_train, y_test = data_split(comb_dat, 'dna', 0.15)

svm_model, svm_result = ML_train(X_train, X_test, y_train, y_test, 'SVM')
logi_model, logi_result = ML_train(X_train, X_test, y_train, y_test, 'Logistic')
sgd_model, sgd_result = ML_train(X_train, X_test, y_train, y_test, 'SGD')
lgbm_model, lgbm_result = ML_train(X_train, X_test, y_train, y_test, 'LGBM')
# Out:
# Train Target Count: Counter({1: 241, 0: 235})
# Test Target Count: Counter({1: 43, 0: 41})
# Training SVM...
#
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for SVM:
# {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
# Test Result for SVM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92        41
#            1       0.95      0.88      0.92        43
#
#     accuracy                           0.92        84
#    macro avg       0.92      0.92      0.92        84
# weighted avg       0.92      0.92      0.92        84
#
#
# SVM Test Results:
# SVM F1-score :  0.9166, AUC ROC : 0.9671, Accuracy : 0.9167
# Training Logistic...
#
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for Logistic:
# {'C': 0.1, 'penalty': 'l2'}
#
# Test Result for Logistic:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        41
#            1       1.00      0.93      0.96        43
#
#     accuracy                           0.96        84
#    macro avg       0.97      0.97      0.96        84
# weighted avg       0.97      0.96      0.96        84
#
#
# Logistic Test Results:
# Logistic F1-score :  0.9643, AUC ROC : 0.9711, Accuracy : 0.9643
# Training SGD...
#
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for SGD:
# {'alpha': 0.0001, 'penalty': 'l1'}
#
# Test Result for SGD:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        41
#            1       0.95      0.93      0.94        43
#
#     accuracy                           0.94        84
#    macro avg       0.94      0.94      0.94        84
# weighted avg       0.94      0.94      0.94        84
#
#
# SGD Test Results:
# SGD F1-score :  0.9405, AUC ROC : 0.9648, Accuracy : 0.9405
# Training LGBM...
#
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [LightGBM] [Info] Number of positive: 241, number of negative: 235
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008762 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 117209
# [LightGBM] [Info] Number of data points in the train set: 476, number of used features: 736
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.506303 -> initscore=0.025211
# [LightGBM] [Info] Start training from score 0.025211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Fold 1 Training ................
#
# Fold 2 Training ................
#
# Fold 3 Training ................
#
# Fold 4 Training ................
#
# Fold 5 Training ................
#
# Best Parameters for LGBM:
# {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#
# Test Result for LGBM:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94        41
#            1       0.97      0.91      0.94        43
#
#     accuracy                           0.94        84
#    macro avg       0.94      0.94      0.94        84
# weighted avg       0.94      0.94      0.94        84
#
#
# LGBM Test Results:
# LGBM F1-score :  0.9405, AUC ROC : 0.9558, Accuracy : 0.9405

# %%
# Save Validation Results
svm_res = val_result(val_df, svm_model)
logi_res = val_result(val_df, logi_model)
sgd_res = val_result(val_df, sgd_model)
lgbm_res = val_result(val_df, lgbm_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.97      0.68        30
#            1       0.80      0.13      0.23        30
#
#     accuracy                           0.55        60
#    macro avg       0.66      0.55      0.46        60
# weighted avg       0.66      0.55      0.46        60
#
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71        30
#            1       1.00      0.17      0.29        30
#
#     accuracy                           0.58        60
#    macro avg       0.77      0.58      0.50        60
# weighted avg       0.77      0.58      0.50        60
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.93      0.67        30
#            1       0.67      0.13      0.22        30
#
#     accuracy                           0.53        60
#    macro avg       0.59      0.53      0.44        60
# weighted avg       0.59      0.53      0.44        60
#
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70        30
#            1       1.00      0.13      0.24        30
#
#     accuracy                           0.57        60
#    macro avg       0.77      0.57      0.47        60
# weighted avg       0.77      0.57      0.47        60

# %%
results = [svm_res, logi_res, sgd_res, lgbm_res]
model_names = ["SVM", "Logistic Regression", "SGD", "LightGBM"]

vis_bar(results, model_names)
